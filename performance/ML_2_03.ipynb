# %%
grades = [
    {'Pos': 23, 'Neg': 1500, 'TP': 19, 'TN': 1498, 'FP': 2, 'FN': 4, 'Accuracy': 0.9960604070912672, 'Precision': 0.9047619047619048, 'Recall': 0.8260869565217391, 'desc': 'nn Aaditi', 'set': 'test'},
    {'Pos': 23, 'Neg': 1500, 'TP': 18, 'TN': 1495, 'FP': 5, 'FN': 5, 'Accuracy': 0.9934340118187788, 'Precision': 0.782608695652174, 'Recall': 0.782608695652174, 'desc': 'nn Batool', 'set': 'train'},
    {'Pos': 23, 'Neg': 1500, 'TP': 22, 'TN': 1500, 'FP': 0, 'FN': 1, 'Accuracy': 0.9993434011818779, 'Precision': 1.0, 'Recall': 0.9565217391304348, 'desc': 'nn Dan', 'set': 'test'},
    {'Pos': 23, 'Neg': 1500, 'TP': 22, 'TN': 1494, 'FP': 6, 'FN': 1, 'Accuracy': 0.9954038082731451, 'Precision': 0.7857142857142857, 'Recall': 0.9565217391304348, 'desc': 'prc Fifi', 'set': 'train'},
    {'Pos': 23, 'Neg': 1500, 'TP': 23, 'TN': 1498, 'FP': 2, 'FN': 0, 'Accuracy': 0.9986868023637557, 'Precision': 0.92, 'Recall': 1.0, 'desc': 'nn Mio', 'set': 'test'},
    {'Pos': 23, 'Neg': 1500, 'TP': 21, 'TN': 1496, 'FP': 4, 'FN': 2, 'Accuracy': 0.9960604070912672, 'Precision': 0.84, 'Recall': 0.9130434782608695, 'desc': 'prc Shirley', 'set': 'train'},
    {'Pos': 23, 'Neg': 1500, 'TP': 20, 'TN': 1498, 'FP': 2, 'FN': 3, 'Accuracy': 0.9967170059093894, 'Precision': 0.9090909090909091, 'Recall': 0.8695652173913043, 'desc': 'nn Yashwanth', 'set': 'test'},
    {'Pos': 23, 'Neg': 1500, 'TP': 15, 'TN': 1499, 'FP': 1, 'FN': 8, 'Accuracy': 0.9940906106369009, 'Precision': 0.9375, 'Recall': 0.6521739130434783, 'desc': 'nn Tresson', 'set': 'train'},
    {'Pos': 23, 'Neg': 1500, 'TP': 18, 'TN': 1500, 'FP': 0, 'FN': 5, 'Accuracy': 0.9967170059093894, 'Precision': 1.0, 'Recall': 0.782608695652174, 'desc': 'nn June', 'set': 'train'},
    {'Pos': 23, 'Neg': 1500, 'TP': 6, 'TN': 1500, 'FP': 0, 'FN': 17, 'Accuracy': 0.9888378200919238, 'Precision': 1.0, 'Recall': 0.2608695652173913, 'desc': 'nn Mahsa', 'set': 'train'}
]

# %%
len(grades)
# Out:
# 10

# %%
# displace labels
lengths = [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15, 15)

for fit in grades:
    plt.plot(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], 'ro')
#     plt.text(fit['FP'] / fit['Neg'], 
    plt.text(fit['FP'] / fit['Neg'] + len(lengths[fit['TP']]) * 0.1, 
             fit['TP'] / fit['Pos'], fit['desc'])
    lengths[fit['TP']].append(True)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.figure(figsize=(50,50))
plt.show()
