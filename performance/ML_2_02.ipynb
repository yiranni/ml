# %%
grades = [
    {'Pos': 23, 'Neg': 1500, 'TP': 19, 'TN': 1498, 'FP': 2, 'FN': 4, 'Accuracy': 0.9960604070912672, 'Precision': 0.9047619047619048, 'Recall': 0.8260869565217391, 'desc': 'nn Aaditi', 'set': 'test'},
    {'Pos': 23, 'Neg': 1500, 'TP': 15, 'TN': 1500, 'FP': 0, 'FN': 8, 'Accuracy': 0.9947472094550229, 'Precision': 1.0, 'Recall': 0.6521739130434783, 'desc': 'nn Aariti', 'set': 'train'},
    {'Pos': 23, 'Neg': 1500, 'TP': 14, 'TN': 1496, 'FP': 4, 'FN': 9, 'Accuracy': 0.9914642153644123, 'Precision': 0.7777777777777778, 'Recall': 0.6086956521739131, 'desc': 'nn Ang', 'set': 'train'},
    {'Pos': 23, 'Neg': 1500, 'TP': 17, 'TN': 1498, 'FP': 2, 'FN': 6, 'Accuracy': 0.9947472094550229, 'Precision': 0.8947368421052632, 'Recall': 0.7391304347826086, 'desc': 'nn Batool', 'set': 'train'},
    {'Pos': 23, 'Neg': 1500, 'TP': 11, 'TN': 1494, 'FP': 6, 'FN': 12, 'Accuracy': 0.9881812212738017, 'Precision': 0.6470588235294118, 'Recall': 0.4782608695652174, 'desc': 'prc Bowen', 'set': 'test'},
    {'Pos': 23, 'Neg': 1500, 'TP': 20, 'TN': 1498, 'FP': 2, 'FN': 3, 'Accuracy': 0.9967170059093894, 'Precision': 0.9090909090909091, 'Recall': 0.8695652173913043, 'desc': 'nn Dan', 'set': 'test'},
    {'Pos': 23, 'Neg': 1500, 'TP': 22, 'TN': 1499, 'FP': 1, 'FN': 1, 'Accuracy': 0.9986868023637557, 'Precision': 0.9565217391304348, 'Recall': 0.9565217391304348, 'desc': 'nn Felix'},
    {'Pos': 23, 'Neg': 1500, 'TP': 22, 'TN': 1496, 'FP': 4, 'FN': 1, 'Accuracy': 0.9967170059093894, 'Precision': 0.8461538461538461, 'Recall': 0.9565217391304348, 'desc': 'nn Fifi', 'set': 'train'},
    {'Pos': 23, 'Neg': 1500, 'TP': 14, 'TN': 1498, 'FP': 2, 'FN': 9, 'Accuracy': 0.9927774130006566, 'Precision': 0.875, 'Recall': 0.6086956521739131, 'desc': 'nn Juan', 'set': 'train'},
    {'Pos': 23, 'Neg': 1500, 'TP': 22, 'TN': 1498, 'FP': 2, 'FN': 1, 'Accuracy': 0.9980302035456337, 'Precision': 0.9166666666666666, 'Recall': 0.9565217391304348, 'desc': 'nn Mio', 'set': 'test'},
    {'Pos': 23, 'Neg': 1500, 'TP': 19, 'TN': 1496, 'FP': 4, 'FN': 4, 'Accuracy': 0.9947472094550229, 'Precision': 0.8260869565217391, 'Recall': 0.8260869565217391, 'desc': 'nn Shirley', 'set': 'train'},
    {'Pos': 23, 'Neg': 1500, 'TP': 22, 'TN': 1500, 'FP': 0, 'FN': 1, 'Accuracy': 0.9993434011818779, 'Precision': 1.0, 'Recall': 0.9565217391304348, 'desc': 'nn Shuyu', 'set': 'test'},
    {'Pos': 23, 'Neg': 1500, 'TP': 12, 'TN': 1499, 'FP': 1, 'FN': 11, 'Accuracy': 0.9921208141825345, 'Precision': 0.9230769230769231, 'Recall': 0.5217391304347826, 'desc': 'nn Simone', 'set': 'train'},
    {'Pos': 23, 'Neg': 1500, 'TP': 23, 'TN': 1500, 'FP': 0, 'FN': 0, 'Accuracy': 1.0, 'Precision': 1.0, 'Recall': 1.0, 'desc': 'nn Tima', 'set': 'train'},
    {'Pos': 23, 'Neg': 1500, 'TP': 21, 'TN': 1492, 'FP': 8, 'FN': 2, 'Accuracy': 0.9934340118187788, 'Precision': 0.7241379310344828, 'Recall': 0.9130434782608695, 'desc': 'nn Yashwanth', 'set': 'test'},
    {'Pos': 23, 'Neg': 1500, 'TP': 19, 'TN': 1499, 'FP': 1, 'FN': 4, 'Accuracy': 0.9967170059093894, 'Precision': 0.95, 'Recall': 0.8260869565217391, 'desc': 'nn Zui', 'set': 'test'}
]

# %%
len(grades)
# Out:
# 16

# %%
# displace labels
lengths = [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15, 15)

for fit in grades:
    plt.plot(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], 'ro')
#     plt.text(fit['FP'] / fit['Neg'], 
    plt.text(fit['FP'] / fit['Neg'] + len(lengths[fit['TP']]) * 0.1, 
             fit['TP'] / fit['Pos'], fit['desc'])
    lengths[fit['TP']].append(True)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.figure(figsize=(50,50))
plt.show()
