# %%
grades = [{'Pos': 23, 'Neg': 1500, 'TP': 10, 'TN': 1499, 'FP': 1, 'FN': 13, 'Accuracy': 0.9908076165462902, 'Precision': 0.9090909090909091, 'Recall': 0.43478260869565216, 'desc': 'nn Aaditi', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 10, 'TN': 1500, 'FP': 0, 'FN': 13, 'Accuracy': 0.9914642153644123, 'Precision': 1.0, 'Recall': 0.43478260869565216, 'desc': 'nn Alya', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 21, 'TN': 1500, 'FP': 0, 'FN': 2, 'Accuracy': 0.9986868023637557, 'Precision': 1.0, 'Recall': 0.9130434782608695, 'desc': 'nn Andrew', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 11, 'TN': 1499, 'FP': 1, 'FN': 12, 'Accuracy': 0.9914642153644123, 'Precision': 0.9166666666666666, 'Recall': 0.4782608695652174, 'desc': 'nn Ang', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 13, 'TN': 1499, 'FP': 1, 'FN': 10, 'Accuracy': 0.9927774130006566, 'Precision': 0.9285714285714286, 'Recall': 0.5652173913043478, 'desc': 'svm Batool', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 11, 'TN': 1494, 'FP': 6, 'FN': 12, 'Accuracy': 0.9881812212738017, 'Precision': 0.6470588235294118, 'Recall': 0.4782608695652174, 'desc': 'prc Bowen', 'set': 'test'}, {'Pos': 23, 'Neg': 1500, 'TP': 19, 'TN': 1500, 'FP': 0, 'FN': 4, 'Accuracy': 0.9973736047275115, 'Precision': 1.0, 'Recall': 0.8260869565217391, 'desc': 'prc Dan', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 22, 'TN': 1499, 'FP': 1, 'FN': 1, 'Accuracy': 0.9986868023637557, 'Precision': 0.9565217391304348, 'Recall': 0.9565217391304348, 'desc': 'nn Fady', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 20, 'TN': 1500, 'FP': 0, 'FN': 3, 'Accuracy': 0.9980302035456337, 'Precision': 1.0, 'Recall': 0.8695652173913043, 'desc': 'nn Felix', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 19, 'TN': 1500, 'FP': 0, 'FN': 4, 'Accuracy': 0.9973736047275115, 'Precision': 1.0, 'Recall': 0.8260869565217391, 'desc': 'prc Fifi', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 11, 'TN': 1493, 'FP': 7, 'FN': 12, 'Accuracy': 0.9875246224556796, 'Precision': 0.6111111111111112, 'Recall': 0.4782608695652174, 'desc': 'nn Jerry', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 6, 'TN': 1499, 'FP': 1, 'FN': 17, 'Accuracy': 0.9881812212738017, 'Precision': 0.8571428571428571, 'Recall': 0.2608695652173913, 'desc': 'nn Juan', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 20, 'TN': 1500, 'FP': 0, 'FN': 3, 'Accuracy': 0.9980302035456337, 'Precision': 1.0, 'Recall': 0.8695652173913043, 'desc': 'nn June', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 14, 'TN': 1500, 'FP': 0, 'FN': 9, 'Accuracy': 0.9940906106369009, 'Precision': 1.0, 'Recall': 0.6086956521739131, 'desc': 'nn Karen', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 9, 'TN': 1498, 'FP': 2, 'FN': 14, 'Accuracy': 0.989494418910046, 'Precision': 0.8181818181818182, 'Recall': 0.391304347826087, 'desc': 'nn Mahsa', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 19, 'TN': 1498, 'FP': 2, 'FN': 4, 'Accuracy': 0.9960604070912672, 'Precision': 0.9047619047619048, 'Recall': 0.8260869565217391, 'desc': 'prc Mio', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 17, 'TN': 1496, 'FP': 4, 'FN': 6, 'Accuracy': 0.9934340118187788, 'Precision': 0.8095238095238095, 'Recall': 0.7391304347826086, 'desc': 'nn Shirley', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 20, 'TN': 1500, 'FP': 0, 'FN': 3, 'Accuracy': 0.9980302035456337, 'Precision': 1.0, 'Recall': 0.8695652173913043, 'desc': 'prc Shuyu', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 14, 'TN': 1494, 'FP': 6, 'FN': 9, 'Accuracy': 0.990151017728168, 'Precision': 0.7, 'Recall': 0.6086956521739131, 'desc': 'nn Simone', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 22, 'TN': 1500, 'FP': 0, 'FN': 1, 'Accuracy': 0.9993434011818779, 'Precision': 1.0, 'Recall': 0.9565217391304348, 'desc': 'nn Tima', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 21, 'TN': 1492, 'FP': 8, 'FN': 2, 'Accuracy': 0.9934340118187788, 'Precision': 0.7241379310344828, 'Recall': 0.9130434782608695, 'desc': 'prc Yashwanth', 'set': 'train'}, {'Pos': 23, 'Neg': 1500, 'TP': 20, 'TN': 1499, 'FP': 1, 'FN': 3, 'Accuracy': 0.9973736047275115, 'Precision': 0.9523809523809523, 'Recall': 0.8695652173913043, 'desc': 'nn Zui', 'set': 'train'}]

# %%
len(grades)
# Out:
# 22

# %%
# displace labels
lengths = [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15, 15)

for fit in grades:
    plt.plot(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], 'ro')
#     plt.text(fit['FP'] / fit['Neg'], 
    plt.text(fit['FP'] / fit['Neg'] + len(lengths[fit['TP']]) * 0.1, 
             fit['TP'] / fit['Pos'], fit['desc'])
    lengths[fit['TP']].append(True)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.figure(figsize=(50,50))
plt.show()
