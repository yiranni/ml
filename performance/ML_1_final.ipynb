# %%
grades = [
    {'Pos': 8427, 'Neg': 105027, 'TP': 2737, 'TN': 98438, 'FP': 6589, 'FN': 5690, 'Accuracy': 0.8917711142842033, 'Precision': 0.2934805918936307, 'Recall': 0.3247893675091966, 'desc': 'lgs Aaditi'},
    {'Pos': 8427, 'Neg': 105027, 'TP': 2533, 'TN': 104950, 'FP': 77, 'FN': 5894, 'Accuracy': 0.9473707405644578, 'Precision': 0.9704980842911878, 'Recall': 0.3005814643408093, 'desc': 'rf Aarati'},
    {'Pos': 8427, 'Neg': 105027, 'TP': 3488, 'TN': 101016, 'FP': 4011, 'FN': 4939, 'Accuracy': 0.9211134027887955, 'Precision': 0.46512868382450995, 'Recall': 0.41390767770262255, 'desc': 'dtc Andrew'},
    {'Pos': 8427, 'Neg': 105027, 'TP': 3359, 'TN': 88972, 'FP': 16055, 'FN': 5068, 'Accuracy': 0.8138188164366175, 'Precision': 0.17301947048521685, 'Recall': 0.3985997389343776, 'desc': 'nbs Ang'},
    {'Pos': 8427, 'Neg': 105027, 'TP': 3840, 'TN': 92909, 'FP': 12118, 'FN': 4587, 'Accuracy': 0.8527597087806512, 'Precision': 0.2406316581025191, 'Recall': 0.4556781772872909, 'desc': 'svm Batool'},
    {'Pos': 22449, 'Neg': 91005, 'TP': 15284, 'TN': 76498, 'FP': 14507, 'FN': 7165, 'Accuracy': 0.8089798508646676, 'Precision': 0.5130408512638045, 'Recall': 0.680832108334447, 'desc': 'rf Fady'},
    {'Pos': 37157, 'Neg': 76297, 'TP': 20295, 'TN': 63482, 'FP': 12815, 'FN': 16862, 'Accuracy': 0.7384226206215735, 'Precision': 0.6129568106312292, 'Recall': 0.5461958715719784, 'desc': 'ens Felix'},
    {'Pos': 8427, 'Neg': 105027, 'TP': 3791, 'TN': 78904, 'FP': 26123, 'FN': 4636, 'Accuracy': 0.7288857157967106, 'Precision': 0.1267299592164204, 'Recall': 0.4498635338791978, 'desc': 'dtc Fifi'},
    {'Pos': 8427, 'Neg': 105027, 'TP': 1868, 'TN': 96029, 'FP': 8998, 'FN': 6559, 'Accuracy': 0.8628783471715409, 'Precision': 0.17191238726302227, 'Recall': 0.2216684466595467, 'desc': 'svm Jerry'},
    {'Pos': 5111, 'Neg': 108343, 'TP': 1814, 'TN': 98849, 'FP': 9494, 'FN': 3297, 'Accuracy': 0.887258272075026, 'Precision': 0.16041740360806508, 'Recall': 0.354920759146938, 'desc': 'nbs June'},
    {'Pos': 8427, 'Neg': 105027, 'TP': 3348, 'TN': 89654, 'FP': 15373, 'FN': 5079, 'Accuracy': 0.8197331076912229, 'Precision': 0.17883660060894183, 'Recall': 0.3972944108223567, 'desc': 'nbs Mahsa'},
    {'Pos': 45351, 'Neg': 68103, 'TP': 27847, 'TN': 50098, 'FP': 18005, 'FN': 17504, 'Accuracy': 0.6870185273326634, 'Precision': 0.6073235627671639, 'Recall': 0.6140327666424115, 'desc': 'rdg Mio'},
    {'Pos': 8427, 'Neg': 105027, 'TP': 3493, 'TN': 100910, 'FP': 4117, 'FN': 4934, 'Accuracy': 0.9202231741498758, 'Precision': 0.4590013140604468, 'Recall': 0.414501008662632, 'desc': 'dtc Shirley'},
    {'Pos': 8427, 'Neg': 105027, 'TP': 2074, 'TN': 98475, 'FP': 6552, 'FN': 6353, 'Accuracy': 0.8862534595518888, 'Precision': 0.24043589149084163, 'Recall': 0.24611368221193783, 'desc': 'svm Simone'},
    {'Pos': 8427, 'Neg': 105027, 'TP': 3351, 'TN': 81170, 'FP': 23857, 'FN': 5076, 'Accuracy': 0.7449803444567843, 'Precision': 0.12316230520435166, 'Recall': 0.3976504093983624, 'desc': 'dtc Tresson'},
    {'Recall': 0.5734302709847984, 'Pos': 22695, 'Precision': 0.5450890052356021, 'Accuracy': 0.8189398346466409, 'Neg': 90759, 'TP': 13014, 'TN': 79898, 'desc': 'rf Tima', 'FP': 10861, 'FN': 9681},
    {'Pos': 8427, 'Neg': 105027, 'TP': 3357, 'TN': 89093, 'FP': 15934, 'FN': 5070, 'Accuracy': 0.8148676996844536, 'Precision': 0.17401897257788607, 'Recall': 0.3983624065503738, 'desc': 'nbs Yashwanth'},
    {'Pos': 8427, 'Neg': 105027, 'TP': 4097, 'TN': 75907, 'FP': 29120, 'FN': 4330, 'Accuracy': 0.7051668517637104, 'Precision': 0.1233404581991149, 'Recall': 0.4861753886317788, 'desc': 'nbs Shuyu'},
    {'Pos': 59724, 'Neg': 53730, 'TP': 45412, 'TN': 39759, 'FP': 13971, 'FN': 14312, 'Accuracy': 0.7507095386676539, 'Precision': 0.764730646818113, 'Recall': 0.7603643426428237, 'desc': 'dtc Dan'},
    {'Pos': 8427, 'Neg': 105027, 'TP': 3165, 'TN': 99937, 'FP': 5090, 'FN': 5262, 'Accuracy': 0.9087559715831968, 'Precision': 0.38340399757722593, 'Recall': 0.37557849768600926, 'desc': 'dtc Juan'},
    {'Pos': 8427, 'Neg': 105027, 'TP': 2983, 'TN': 85795, 'FP': 19232, 'FN': 5444, 'Accuracy': 0.7825021594655103, 'Precision': 0.13427864055818142, 'Recall': 0.3539812507416637, 'desc': 'nbs Karen'},
    {'Pos': 8427, 'Neg': 105027, 'TP': 3485, 'TN': 87776, 'FP': 17251, 'FN': 4942, 'Accuracy': 0.8043876813510321, 'Precision': 0.16806520061728394, 'Recall': 0.41355167912661683, 'desc': 'nbs Nicole'},
    {'Pos': 8427, 'Neg': 105027, 'TP': 4660, 'TN': 76480, 'FP': 28547, 'FN': 3767, 'Accuracy': 0.7151797204153225, 'Precision': 0.14033185774083778, 'Recall': 0.5529844547288477, 'desc': 'nbs Alya'},
    {'Pos': 8427, 'Neg': 105027, 'TP': 1032, 'TN': 99019, 'FP': 6008, 'FN': 7395, 'Accuracy': 0.8818640153718688, 'Precision': 0.14659090909090908, 'Recall': 0.12246351014595942, 'desc': 'prc Zui'}
]

len(grades)
# Out:
# 24

# %%
for grade in grades:
    grade['name'] = grade['desc'].split()[1]
    grade['model'] = grade['desc'].split()[0]

for grade in grades:
    if (grade['desc'].split()[0]=='dtc'):
        grade['color'] = 'ro'
    elif (grade['desc'].split()[0]=='lgs'):
        grade['color'] = 'bo'
    elif (grade['desc'].split()[0]=='nbs'):
        grade['color'] = 'go'
    elif (grade['desc'].split()[0]=='rdg'):
        grade['color'] = 'yo'
    elif (grade['desc'].split()[0]=='rf'):
        grade['color'] = 'co'
    elif (grade['desc'].split()[0]=='svm'):
        grade['color'] = 'mo'
    elif (grade['desc'].split()[0]=='ens'):
        grade['color'] = 'ko'
    elif (grade['desc'].split()[0]=='prc'):
        grade['color'] = 'ko'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (25, 25)

# %%
for fit in grades:
    plt.plot(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], fit['color'])
    plt.text(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], fit['name'] + ' ' + fit['model'])
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()

# %% [markdown]
# ### individual performance

# %%
plt.rcParams['figure.figsize'] = (10, 10)

# %%
for fit in grades:
    print(fit['name'] + ':')
    for fitt in grades:
        plt.plot(fitt['FP'] / fitt['Neg'], 
             fitt['TP'] / fitt['Pos'], 'o', color='0.75')
    plt.plot(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], fit['color'])
    plt.text(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], fit['name'] + ' ' + fit['model'])
    plt.axis([0, 1, 0, 1])
    plt.title('ROC plot: test set')
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.show()
    print('* * *')
# Out:
# Aaditi:
# * * *
# Aarati:
# * * *
# Andrew:
# * * *
# Ang:
# * * *
# Batool:
# * * *
# Fady:
# * * *
# Felix:
# * * *
# Fifi:
# * * *
# Jerry:
# * * *
# June:
# * * *
# Mahsa:
# * * *
# Mio:
# * * *
# Shirley:
# * * *
# Simone:
# * * *
# Tresson:
# * * *
# Tima:
# * * *
# Yashwanth:
# * * *
# Shuyu:
# * * *
# Dan:
# * * *
# Juan:
# * * *
# Karen:
# * * *
# Nicole:
# * * *
# Alya:
# * * *
# Zui:
# * * *
