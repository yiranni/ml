# %%
grades = [{'TP': 3593, 'color': 'bo', 'FN': 4834, 'Precision': 0.21978223635918767, 'TN': 92272, 'Recall': 0.4263676278628219, 'desc': 'nbs Aucher', 'Pos': 8427, 'Accuracy': 0.8449680046538686, 'Neg': 105027, 'name': 'Aucher', 'FP': 12755, 'model': 'nbs'}, {'model': 'unspecified', 'TP': 5379, 'Pos': 9949, 'color': 'yo', 'FN': 9789, 'desc': 'unspecified Benz', 'Neg': 103505, 'name': 'Benz', 'Accuracy': 0.8734376928094205, 'TN': 93716, 'FP': 4570}, {'TP': 3422, 'color': 'bo', 'FN': 5005, 'desc': 'multilayer Eduardo', 'TN': 98926, 'Recall': 0.4060757090304972, 'Precision': 0.35934054394623544, 'Pos': 8427, 'Accuracy': 0.902110106298588, 'Neg': 105027, 'name': 'Eduardo', 'FP': 6101, 'model': 'multilayer'}, {'TP': 7213, 'color': 'ro', 'FN': 1214, 'Precision': 0.13451317531656193, 'TN': 58617, 'Recall': 0.855939242909695, 'desc': 'rdg Emily', 'Pos': 8427, 'Accuracy': 0.5802351613869938, 'Neg': 105027, 'name': 'Emily', 'FP': 46410, 'model': 'rdg'}, {'TP': 4342, 'color': 'ro', 'FN': 4085, 'desc': 'rdg George', 'TN': 86707, 'Recall': 0.515248605672244, 'Precision': 0.1915982702321066, 'Pos': 8427, 'Accuracy': 0.8025190826237947, 'Neg': 105027, 'name': 'George', 'FP': 18320, 'model': 'rdg'}, {'TP': 3634, 'color': 'go', 'FN': 4793, 'desc': 'lgs Jason', 'TN': 96378, 'Recall': 0.43123294173489973, 'Precision': 0.2958560612228283, 'Pos': 8427, 'Accuracy': 0.8815202637192165, 'Neg': 105027, 'name': 'Jason', 'FP': 8649, 'model': 'lgs'}, {'TP': 5534, 'color': 'go', 'FN': 2893, 'desc': 'lgs Kevin', 'TN': 66814, 'Recall': 0.6566987065385071, 'Precision': 0.1265001028641964, 'Pos': 8427, 'Accuracy': 0.6376857581046063, 'Neg': 105027, 'name': 'Kevin', 'FP': 38213, 'model': 'lgs'}, {'model': 'unspecified', 'Pos': 2847, 'color': 'yo', 'FN': 6892, 'desc': 'unspecified Rik', 'Neg': 110607, 'name': 'Rik', 'Accuracy': 0.9276887549138858, 'TP': 1535, 'TN': 103715, 'FP': 1312}, {'TP': 3166, 'color': 'bo', 'FN': 5261, 'desc': 'nbs Yicen', 'TN': 91324, 'Recall': 0.37569716387801116, 'Precision': 0.18768154603118145, 'Pos': 8427, 'Accuracy': 0.8328485553616444, 'Neg': 105027, 'name': 'Yicen', 'FP': 13703, 'model': 'nbs'}, {'TP': 2647, 'color': 'bo', 'FN': 5780, 'desc': 'nbs Ellie', 'TN': 70598, 'Recall': 0.3141094102290258, 'Precision': 0.07139389362390765, 'Pos': 8427, 'Accuracy': 0.6455920461156063, 'Neg': 105027, 'name': 'Ellie', 'FP': 34429, 'model': 'nbs'}, {'TP': 3059, 'color': 'bo', 'FN': 5368, 'Precision': 0.19193123352992847, 'TN': 92148, 'Recall': 0.362999881333808, 'desc': 'nbs Flavio', 'Pos': 8427, 'Accuracy': 0.8391682972834805, 'Neg': 105027, 'name': 'Flavio', 'FP': 12879, 'model': 'nbs'}, {'TP': 4774, 'color': 'ro', 'FN': 3653, 'desc': 'rdg Philipp', 'TN': 72800, 'Recall': 0.5665124006170642, 'Precision': 0.1290235399043269, 'Pos': 8427, 'Accuracy': 0.6837484795599978, 'Neg': 105027, 'name': 'Philipp', 'FP': 32227, 'model': 'rdg'}, {'TP': 3396, 'color': 'ro', 'FN': 5031, 'desc': 'rdg Michael', 'TN': 98254, 'Recall': 0.40299038803844783, 'Precision': 0.333956141213492, 'Pos': 8427, 'Accuracy': 0.895957833130608, 'Neg': 105027, 'name': 'Michael', 'FP': 6773, 'model': 'rdg'}, {'TP': 5826, 'color': 'mo', 'FN': 7069, 'desc': 'prc Steve', 'TN': 85812, 'Recall': 0.4518030244280729, 'Precision': 0.2831867010158946, 'Pos': 12895, 'Accuracy': 0.8077106139933365, 'Neg': 100559, 'name': 'Steve', 'FP': 14747, 'model': 'prc'}, {'TP': 7178, 'color': 'go', 'FN': 1249, 'desc': 'lgs Alonso', 'TN': 24157, 'Recall': 0.8517859261896286, 'Precision': 0.08152371433763402, 'Pos': 8427, 'Accuracy': 0.27619123168861387, 'Neg': 105027, 'name': 'Alonso', 'FP': 80870, 'model': 'lgs'}, {'TP': 4383, 'color': 'bo', 'FN': 4044, 'desc': 'nbs Andrew', 'TN': 83406, 'Recall': 0.5201139195443218, 'Precision': 0.16855099215505306, 'Pos': 8427, 'Accuracy': 0.7737849701200487, 'Neg': 105027, 'name': 'Andrew', 'FP': 21621, 'model': 'nbs'}]

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15, 15)

for fit in grades:
    plt.plot(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], fit['color'])
    plt.text(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], fit['name'] + ' ' + fit['model'])
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.figure(figsize=(50,50))
plt.show()

# %%
n = [113454, 113454, 113454, 113454, 113454, 113454, 113454, 113454, 113454, 113454, 113454, 113454, 113454, 113454]

print(min(n))
print(max(n))
# Out:
# 113454
# 113454
