# %%
grades = [{'desc': 'nbs Aucher', 'Pos': 8427, 'Accuracy': 0.8449680046538686, 'FP': 12755, 'FN': 4834, 'Precision': 0.21978223635918767, 'TN': 92272, 'TP': 3593, 'Neg': 105027, 'Recall': 0.4263676278628219, 'name': 'Aucher', 'color': 'bo', 'model': 'nbs'}, {'desc': 'unspecified Benz', 'Neg': 103505, 'FN': 9789, 'TP': 5379, 'TN': 93716, 'Pos': 9949, 'FP': 4570, 'Accuracy': 0.8734376928094205, 'name': 'Benz', 'color': 'yo', 'model': 'unspecified'}, {'FP': 6101, 'Pos': 8427, 'Recall': 0.4060757090304972, 'Neg': 105027, 'Precision': 0.35934054394623544, 'Accuracy': 0.902110106298588, 'TP': 3422, 'desc': 'multilayer Eduardo', 'TN': 98926, 'FN': 5005, 'name': 'Eduardo', 'color': 'bo', 'model': 'multilayer'}, {'TP': 7213, 'Neg': 105027, 'TN': 58617, 'desc': 'rdg Emily', 'Recall': 0.855939242909695, 'FN': 1214, 'Precision': 0.13451317531656193, 'Pos': 8427, 'FP': 46410, 'Accuracy': 0.5802351613869938, 'name': 'Emily', 'color': 'ro', 'model': 'rdg'}, {'Pos': 8427, 'Neg': 105027, 'TP': 4342, 'TN': 86707, 'FP': 18320, 'FN': 4085, 'Accuracy': 0.8025190826237947, 'Precision': 0.1915982702321066, 'Recall': 0.515248605672244, 'desc': 'rdg George', 'name': 'George', 'color': 'ro', 'model': 'rdg'}, {'Pos': 8427, 'Neg': 105027, 'TP': 3634, 'TN': 96378, 'FP': 8649, 'FN': 4793, 'Accuracy': 0.8815202637192165, 'Precision': 0.2958560612228283, 'Recall': 0.43123294173489973, 'desc': 'lgs Jason', 'name': 'Jason', 'color': 'go', 'model': 'lgs'}, {'Pos': 8427, 'Neg': 105027, 'TP': 5534, 'TN': 66814, 'FP': 38213, 'FN': 2893, 'Accuracy': 0.6376857581046063, 'Precision': 0.1265001028641964, 'Recall': 0.6566987065385071, 'desc': 'lgs Kevin', 'name': 'Kevin', 'color': 'go', 'model': 'lgs'}, {'desc': 'unspecified Rik', 'Pos': 2847, 'Neg': 110607, 'TP': 1535, 'TN': 103715, 'FP': 1312, 'FN': 6892, 'Accuracy': 0.9276887549138858, 'name': 'Rik', 'color': 'yo', 'model': 'unspecified'}, {'Pos': 8427, 'Neg': 105027, 'TP': 3166, 'TN': 91324, 'FP': 13703, 'FN': 5261, 'Accuracy': 0.8328485553616444, 'Precision': 0.18768154603118145, 'Recall': 0.37569716387801116, 'desc': 'nbs Yicen', 'name': 'Yicen', 'color': 'bo', 'model': 'nbs'}, {'Pos': 8427, 'Neg': 105027, 'TP': 2647, 'TN': 70598, 'FP': 34429, 'FN': 5780, 'Accuracy': 0.6455920461156063, 'Precision': 0.07139389362390765, 'Recall': 0.3141094102290258, 'desc': 'nbs Ellie', 'name': 'Ellie', 'color': 'bo', 'model': 'nbs'}, {'Pos': 8427, 'Neg': 105027, 'TP': 3059, 'TN': 92148, 'FP': 12879, 'FN': 5368, 'Accuracy': 0.8391682972834805, 'Precision': 0.19193123352992847, 'Recall': 0.362999881333808, 'desc': 'nbs Flavio', 'name': 'Flavio', 'color': 'bo', 'model': 'nbs'}, {'Pos': 8427, 'Neg': 105027, 'TP': 4774, 'TN': 72800, 'FP': 32227, 'FN': 3653, 'Accuracy': 0.6837484795599978, 'Precision': 0.1290235399043269, 'Recall': 0.5665124006170642, 'desc': 'rdg Philipp', 'name': 'Philipp', 'color': 'ro', 'model': 'rdg'}, {'Pos': 8427, 'Neg': 105027, 'TP': 3396, 'TN': 98254, 'FP': 6773, 'FN': 5031, 'Accuracy': 0.895957833130608, 'Precision': 0.333956141213492, 'Recall': 0.40299038803844783, 'desc': 'rdg Michael', 'name': 'Michael', 'color': 'ro', 'model': 'rdg'}, {'Pos': 12895, 'Neg': 100559, 'TP': 5826, 'TN': 85812, 'FP': 14747, 'FN': 7069, 'Accuracy': 0.8077106139933365, 'Precision': 0.2831867010158946, 'Recall': 0.4518030244280729, 'desc': 'prc Steve', 'name': 'Steve', 'color': 'mo', 'model': 'prc'}]

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15, 15)

for fit in grades:
    plt.plot(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], fit['color'])
    plt.text(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], fit['name'] + ' ' + fit['model'])
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.figure(figsize=(50,50))
plt.show()

# %%
n = [113454, 113454, 113454, 113454, 113454, 113454, 113454, 113454, 113454, 113454, 113454, 113454, 113454, 113454]

print(min(n))
print(max(n))
# Out:
# 113454
# 113454
