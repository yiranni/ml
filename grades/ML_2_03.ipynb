# %%
grades = [{'FN': 7, 'set': 'test', 'Accuracy': 0.9954007884362681, 'TP': 16, 'Precision': 1.0, 'FP': 0, 'Pos': 23, 'Neg': 1499, 'Recall': 0.6956521739130435, 'desc': 'nn_test Aucher', 'TN': 1499}, {'FN': 5, 'set': 'test', 'Accuracy': 0.9940906106369009, 'TP': 18, 'Precision': 0.8181818181818182, 'Recall': 0.782608695652174, 'Pos': 23, 'Neg': 1500, 'FP': 4, 'desc': 'nn_test George', 'TN': 1496}, {'FN': 2, 'set': 'test', 'Accuracy': 0.9973736047275115, 'Precision': 0.9130434782608695, 'FP': 2, 'Pos': 23, 'Neg': 1500, 'Recall': 0.9130434782608695, 'desc': 'nn_test Philipp', 'TN': 1498, 'TP': 21}, {'FN': 11, 'set': 'test Steve', 'Accuracy': 0.989494418910046, 'TP': 12, 'Precision': 0.7058823529411765, 'FP': 5, 'Pos': 23, 'Neg': 1500, 'Recall': 0.5217391304347826, 'desc': 'nn_test Steve', 'TN': 1495}, {'FN': 4, 'set': 'test', 'TN': 1499, 'TP': 19, 'Precision': 0.95, 'Recall': 0.8260869565217391, 'Pos': 23, 'Neg': 1500, 'FP': 1, 'desc': 'nn_test Alonso', 'Accuracy': 0.9967170059093894}, {'FN': 6, 'set': 'test', 'TN': 1498, 'Precision': 0.8947368421052632, 'Recall': 0.7391304347826086, 'Pos': 23, 'Neg': 1500, 'FP': 2, 'desc': 'nn Flavio', 'Accuracy': 0.9947472094550229, 'TP': 17}, {'FN': 5, 'set': 'test Rik', 'TN': 1500, 'TP': 18, 'Precision': 1.0, 'Recall': 0.782608695652174, 'Pos': 23, 'Neg': 1500, 'FP': 0, 'desc': 'nn_test Rik', 'Accuracy': 0.9967170059093894}, {'FN': 8, 'set': 'test', 'TN': 1494, 'TP': 15, 'Precision': 0.7142857142857143, 'Recall': 0.6521739130434783, 'Pos': 23, 'Neg': 1500, 'FP': 6, 'desc': 'nn Nic', 'Accuracy': 0.9908076165462902}, {'FN': 7, 'set': 'test', 'TN': 1492, 'TP': 16, 'Precision': 0.6666666666666666, 'FP': 8, 'Pos': 23, 'Neg': 1500, 'Recall': 0.6956521739130435, 'desc': 'nn_test Benz', 'Accuracy': 0.990151017728168}, {'FN': 13, 'set': 'test', 'TN': 1499, 'Precision': 0.9090909090909091, 'FP': 1, 'Pos': 23, 'Neg': 1500, 'Recall': 0.43478260869565216, 'desc': 'prc Jason', 'Accuracy': 0.9908076165462902, 'TP': 10}, {'FN': 3, 'set': 'test', 'TN': 1500, 'TP': 20, 'Precision': 1.0, 'Recall': 0.8695652173913043, 'Pos': 23, 'Neg': 1500, 'FP': 0, 'desc': 'nn_test Andrew', 'Accuracy': 0.9980302035456337}, {'FN': 1, 'set': 'test', 'Accuracy': 0.9993434011818779, 'TP': 22, 'Precision': 1.0, 'Recall': 0.9565217391304348, 'Pos': 23, 'Neg': 1500, 'FP': 0, 'desc': 'nn_test Kevin', 'TN': 1500}, {'FN': 0, 'set': 'test', 'TN': 1500, 'Precision': 1.0, 'Recall': 1.0, 'Pos': 23, 'Neg': 1500, 'FP': 0, 'desc': 'nn_test Emily', 'Accuracy': 1.0, 'TP': 23}, {'FN': 5, 'set': 'test', 'Accuracy': 0.9914642153644123, 'TP': 18, 'Precision': 0.6923076923076923, 'Recall': 0.782608695652174, 'Pos': 23, 'Neg': 1500, 'FP': 8, 'desc': 'nn_test Yicen', 'TN': 1492}, {'FN': 3, 'set': 'test', 'TN': 1496, 'Precision': 0.8333333333333334, 'FP': 4, 'Pos': 23, 'Neg': 1500, 'Recall': 0.8695652173913043, 'desc': 'nn_test Michael', 'Accuracy': 0.9954038082731451, 'TP': 20}, {'FN': 4, 'set': 'test', 'TN': 375, 'TP': 2, 'Precision': 1.0, 'Recall': 0.3333333333333333, 'Pos': 6, 'Neg': 375, 'FP': 0, 'desc': 'Multi-layer Eduardo', 'Accuracy': 0.989501312335958}]

# %%
# displace labels
lengths = [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15, 15)

for fit in grades:
    plt.plot(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], 'ro')
#     plt.text(fit['FP'] / fit['Neg'], 
    plt.text(fit['FP'] / fit['Neg'] + len(lengths[fit['TP']]) * 0.1, 
             fit['TP'] / fit['Pos'], fit['desc'])
    lengths[fit['TP']].append(True)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.figure(figsize=(50,50))
plt.show()
