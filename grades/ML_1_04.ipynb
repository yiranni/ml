# %%
grades = [{'model': 'unspecified', 'FP': 9658, 'name': 'Benz', 'Neg': 78538, 'desc': 'Benz unspecified', 'color': 'yo', 'Pos': 34916, 'FN': 10857, 'TN': 67681, 'Accuracy': 0.8191778165600155, 'TP': 25258}, {'Precision': 0.17513422372099213, 'FP': 18590, 'name': 'Aucher', 'Accuracy': 0.7966576762388281, 'desc': 'Aucher nbs', 'model': 'nbs', 'TP': 3947, 'Recall': 0.46837545983149403, 'color': 'bo', 'Pos': 8427, 'FN': 4480, 'TN': 86437, 'Neg': 105027}, {'Precision': 0.41324013157894735, 'FP': 4281, 'name': 'Andrew', 'Accuracy': 0.8377034358047016, 'desc': 'Andrew prc', 'model': 'prc', 'TP': 3015, 'Recall': 0.35777856888572446, 'color': 'mo', 'Pos': 8427, 'FN': 5412, 'TN': 47016, 'Neg': 51297}, {'Precision': 0.8016920646246368, 'FP': 7782, 'name': 'Emily', 'Accuracy': 0.767145536132878, 'desc': 'Emily rdg', 'model': 'rdg', 'TP': 31460, 'Recall': 0.8370360516163363, 'color': 'ro', 'Pos': 37585, 'FN': 6125, 'TN': 14357, 'Neg': 22139}, {'Precision': 0.38461538461538464, 'FP': 72, 'name': 'Kevin', 'Accuracy': 0.9990216299116823, 'desc': 'Kevin unspecified', 'model': 'unspecified', 'TP': 45, 'Recall': 0.5357142857142857, 'color': 'yo', 'Pos': 84, 'FN': 39, 'TN': 113298, 'Neg': 113370}, {'Precision': 0.3153225806451613, 'FP': 8490, 'name': 'Nic', 'Accuracy': 0.8853544167680293, 'desc': 'Nic rdg', 'model': 'rdg', 'TP': 3910, 'Recall': 0.46398481072742376, 'color': 'ro', 'Pos': 8427, 'FN': 4517, 'TN': 96537, 'Neg': 105027}, {'Precision': 0.18785344015080113, 'FP': 13787, 'name': 'Rye', 'Accuracy': 0.8323108925203166, 'desc': 'Rye TOP_SECRET', 'model': 'unspecified', 'TP': 3189, 'Recall': 0.37842648629405484, 'color': 'yo', 'Pos': 8427, 'FN': 5238, 'TN': 91240, 'Neg': 105027}, {'model': 'unspecified', 'Pos': 3090, 'FP': 1476, 'name': 'Rik', 'Accuracy': 0.9269395525940028, 'desc': 'Rik unspecified', 'color': 'yo', 'TP': 1614, 'FN': 6813, 'TN': 103551, 'Neg': 110364}, {'Precision': 0.34984074797082093, 'FP': 6328, 'name': 'Steve', 'Accuracy': 0.8310227044404259, 'desc': 'Steve prc', 'model': 'prc', 'TP': 3405, 'Recall': 0.4749616403961501, 'color': 'mo', 'Pos': 7169, 'FN': 3764, 'TN': 46227, 'Neg': 52555}, {'Precision': 0.8025522771343221, 'FP': 7535, 'name': 'Michael', 'Accuracy': 0.754671488848704, 'desc': 'Michael rdg', 'model': 'rdg', 'TP': 30627, 'Recall': 0.8114402289105553, 'color': 'ro', 'Pos': 37744, 'FN': 7117, 'TN': 14445, 'Neg': 21980}]

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15, 15)

for fit in grades:
    plt.plot(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], fit['color'])
    plt.text(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], fit['name'] + ' ' + fit['model'])
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.figure(figsize=(50,50))
plt.show()
