# %%
aucher = {'set': 'test', 'Pos': 23, 'Neg': 1500, 'Accuracy': 0.99540380827314512, 'TP': 17, 'TN': 1499, 'Precision': 0.94444444444444442, 'desc': 'nn_test Aucher', 'FN': 6, 'Recall': 0.73913043478260865, 'FP': 1}
george = {'TN': 1496, 'Neg': 1500, 'Recall': 0.56521739130434778, 'TP': 13, 'set': 'test', 'desc': 'prc George', 'Accuracy': 0.99080761654629024, 'FN': 10, 'Precision': 0.76470588235294112, 'FP': 4, 'Pos': 23}
philipp = {'set': 'test', 'Recall': 0.86956521739130432, 'desc': 'nn_test Philipp', 'TP': 20, 'Neg': 1500, 'Pos': 23, 'TN': 1499, 'FP': 1, 'Precision': 0.95238095238095233, 'FN': 3, 'Accuracy': 0.99737360472751146}
steve = {'FP': 4, 'desc': 'nn_test Steve', 'Neg': 1500, 'Accuracy': 0.99015101772816805, 'FN': 11, 'TP': 12, 'TN': 1496, 'Precision': 0.75, 'Recall': 0.52173913043478259, 'Pos': 23, 'set': 'test'}
alonso = {'Accuracy': 0.99737360472751146, 'TN': 1500, 'FN': 4, 'Neg': 1500, 'FP': 0, 'Recall': 0.82608695652173914, 'TP': 19, 'Pos': 23, 'desc': 'nn_test Alonso', 'set': 'test', 'Precision': 1.0}
flavio = {'TP': 13, 'Precision': 1.0, 'Pos': 23, 'TN': 1500, 'set': 'test', 'FN': 10, 'Neg': 1500, 'Recall': 0.56521739130434778, 'Accuracy': 0.99343401181877877, 'desc': 'nn_test Flavio', 'FP': 0}
rik = {'Accuracy': 0.99671700590938939, 'set': 'test', 'TP': 18, 'FP': 0, 'Recall': 0.78260869565217395, 'Pos': 23, 'Neg': 1500, 'FN': 5, 'Precision': 1.0, 'desc': 'nn_test Rik', 'TN': 1500}
nic = {'Accuracy': 0.98752462245567962, 'Precision': 0.5714285714285714, 'Pos': 23, 'Recall': 0.69565217391304346, 'Neg': 1500, 'TP': 16, 'set': 'test', 'FP': 12, 'FN': 7, 'desc': 'nn nic', 'TN': 1488}
benz = {'TN': 1447, 'FN': 5, 'Recall': 0.78260869565217395, 'FP': 53, 'Neg': 1500, 'Pos': 23, 'Precision': 0.25352112676056338, 'set': 'test', 'desc': 'prc Benz', 'Accuracy': 0.96191726854891657, 'TP': 18}

# %%
grades = [aucher, george, philipp, steve, alonso, flavio, rik, nic, benz]

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15, 15)

for fit in grades:
    plt.plot(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], 'ro')
    plt.text(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], fit['desc'])
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.figure(figsize=(50,50))
plt.show()
