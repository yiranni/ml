# %%
aucher = {'set': 'test', 'Pos': 23, 'Neg': 1500, 'Accuracy': 0.99540380827314512, 'TP': 17, 'TN': 1499, 'Precision': 0.94444444444444442, 'desc': 'nn_test Aucher', 'FN': 6, 'Recall': 0.73913043478260865, 'FP': 1}
george = {'Recall': 0.82608695652173914, 'Pos': 23, 'Accuracy': 0.99474720945502293, 'Neg': 1500, 'desc': 'nn_test George', 'FP': 4, 'Precision': 0.82608695652173914, 'TP': 19, 'FN': 4, 'TN': 1496, 'set': 'test'}
philipp = {'set': 'test', 'Recall': 0.86956521739130432, 'desc': 'nn_test Philipp', 'TP': 20, 'Neg': 1500, 'Pos': 23, 'TN': 1499, 'FP': 1, 'Precision': 0.95238095238095233, 'FN': 3, 'Accuracy': 0.99737360472751146}
steve = {'FP': 4, 'desc': 'nn_test Steve', 'Neg': 1500, 'Accuracy': 0.99015101772816805, 'FN': 11, 'TP': 12, 'TN': 1496, 'Precision': 0.75, 'Recall': 0.52173913043478259, 'Pos': 23, 'set': 'test'}
alonso = {'Accuracy': 0.99737360472751146, 'TN': 1500, 'FN': 4, 'Neg': 1500, 'FP': 0, 'Recall': 0.82608695652173914, 'TP': 19, 'Pos': 23, 'desc': 'nn_test Alonso', 'set': 'test', 'Precision': 1.0}
flavio = {'TP': 13, 'Precision': 1.0, 'Pos': 23, 'TN': 1500, 'set': 'test', 'FN': 10, 'Neg': 1500, 'Recall': 0.56521739130434778, 'Accuracy': 0.99343401181877877, 'desc': 'nn_test Flavio', 'FP': 0}
rik = {'Accuracy': 0.99671700590938939, 'set': 'test', 'TP': 18, 'FP': 0, 'Recall': 0.78260869565217395, 'Pos': 23, 'Neg': 1500, 'FN': 5, 'Precision': 1.0, 'desc': 'nn_test Rik', 'TN': 1500}
nic = {'Accuracy': 0.98752462245567962, 'Precision': 0.5714285714285714, 'Pos': 23, 'Recall': 0.69565217391304346, 'Neg': 1500, 'TP': 16, 'set': 'test', 'FP': 12, 'FN': 7, 'desc': 'nn nic', 'TN': 1488}
benz = {'TN': 1447, 'FN': 5, 'Recall': 0.78260869565217395, 'FP': 53, 'Neg': 1500, 'Pos': 23, 'Precision': 0.25352112676056338, 'set': 'test', 'desc': 'prc Benz', 'Accuracy': 0.96191726854891657, 'TP': 18}
jason = {'TP': 12, 'TN': 1499, 'Recall': 0.52173913043478259, 'set': 'test', 'Precision': 0.92307692307692313, 'Pos': 23, 'FP': 1, 'Neg': 1500, 'FN': 11, 'desc': 'nn_test Jason', 'Accuracy': 0.99212081418253451}
andrew = {'FP': 0, 'FN': 3, 'Pos': 23, 'Neg': 1500, 'TN': 1500, 'set': 'test', 'Accuracy': 0.99803020354563365, 'TP': 20, 'desc': 'nn_test Andrew', 'Recall': 0.86956521739130432, 'Precision': 1.0}
kevin = {'TN': 1500, 'set': 'test', 'TP': 22, 'Precision': 1.0, 'Recall': 0.95652173913043481, 'Pos': 23, 'Neg': 1500, 'Accuracy': 0.99934340118187792, 'FP': 0, 'desc': 'nn_test Kevin', 'FN': 1}
emily = {'Recall': 0.69565217391304346, 'Accuracy': 0.99277741300065658, 'Pos': 23, 'Neg': 1500, 'FN': 7, 'TN': 1496, 'FP': 4, 'Precision': 0.80000000000000004, 'TP': 16, 'desc': 'nn_test Emily', 'set': 'test'}
ellie = {'Pos': 23, 'Neg': 1500, 'TP': 17, 'TN': 1495, 'FP': 5, 'FN': 6, 'Accuracy': 0.99277741300065658, 'Precision': 0.77272727272727271, 'Recall': 0.73913043478260865, 'desc': 'nn Ellie', 'set': 'test'}
michael = {'Pos': 23, 'Neg': 1500, 'TP': 12, 'TN': 1499, 'FP': 1, 'FN': 11, 'Accuracy': 0.9921208141825345, 'Precision': 0.9230769230769231, 'Recall': 0.5217391304347826, 'desc': 'nn_test Michael', 'set': 'test'}
yicen = {'Pos': 23, 'Neg': 1500, 'TP': 17, 'TN': 1495, 'FP': 5, 'FN': 6, 'Accuracy': 0.99277741300065658, 'Precision': 0.77272727272727271, 'Recall': 0.73913043478260865, 'desc': 'nn_test Yicen', 'set': 'test'}
# eduardo = 
# rye =

# %%
grades = [aucher, george, philipp, steve, alonso, flavio, rik, nic, benz, jason, andrew, kevin, emily, yicen, ellie, michael]
print(len(grades))
# Out:
# 16

# %%
# displace labels
lengths = [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15, 15)

for fit in grades:
    plt.plot(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], 'ro')
    plt.text(fit['FP'] / fit['Neg'] + len(lengths[fit['TP']]) * 0.1, 
             fit['TP'] / fit['Pos'], fit['desc'])
    lengths[fit['TP']].append(True)
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.figure(figsize=(50,50))
plt.show()
