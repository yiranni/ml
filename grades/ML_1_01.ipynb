# %%
grades = [{'FN': 5244, 'Accuracy': 0.8731644543162868, 'model': 'nbs', 'Precision': 0.25817179008840946, 'name': 'Alonso', 'Neg': 105027, 'FP': 9146, 'color': 'bo', 'Recall': 0.3777144891420434, 'TP': 3183, 'TN': 95881, 'Pos': 8427, 'desc': 'nbs Alonso'}, {'FN': 5333, 'Accuracy': 0.8353341442346678, 'model': 'nbs', 'Precision': 0.1881651766709238, 'name': 'Andrew', 'Neg': 105027, 'FP': 13349, 'color': 'bo', 'Recall': 0.3671531980538745, 'TP': 3094, 'TN': 91678, 'Pos': 8427, 'desc': 'nbs Andrew'}, {'FN': 5112, 'Accuracy': 0.8226505896662965, 'model': 'nbs', 'Precision': 0.1809102815979044, 'name': 'Aucher', 'Neg': 105027, 'FP': 15009, 'color': 'bo', 'Recall': 0.39337842648629406, 'TP': 3315, 'TN': 90018, 'Pos': 8427, 'desc': 'nbs Aucher'}, {'FN': 10503, 'model': 'unspecified', 'Accuracy': 0.7819733107691222, 'color': 'yo', 'name': 'Benz', 'Neg': 94556, 'TP': 4665, 'TN': 84053, 'Pos': 18898, 'desc': 'unspecified Benz', 'FP': 14233}, {'FN': 7089, 'Accuracy': 0.9222063567613306, 'model': 'rdg', 'Precision': 0.4351219512195122, 'name': 'Eduardo', 'Neg': 105027, 'FP': 1737, 'color': 'ro', 'Recall': 0.1587753648985404, 'TP': 1338, 'TN': 103290, 'Pos': 8427, 'desc': 'ridge_1 Eduardo'}, {'FN': 6193, 'Accuracy': 0.9146438204029828, 'model': 'lgs', 'Precision': 0.3902183406113537, 'name': 'Ellie', 'Neg': 105027, 'FP': 3491, 'color': 'go', 'Recall': 0.2651002729322416, 'TP': 2234, 'TN': 101536, 'Pos': 8427, 'desc': 'lgs_001 Ellie'}, {'FN': 6277, 'Accuracy': 0.8824545630828353, 'model': 'svm', 'Precision': 0.23346726028884787, 'name': 'Flavio', 'Neg': 105027, 'FP': 7059, 'color': 'co', 'Recall': 0.2551323128040821, 'TP': 2150, 'TN': 97968, 'Pos': 8427, 'desc': 'svm Flavio'}, {'FN': 5318, 'Accuracy': 0.9082711936115078, 'model': 'prc', 'Precision': 0.3792388387411564, 'name': 'George', 'Neg': 105027, 'FP': 5089, 'color': 'mo', 'Recall': 0.3689331909339029, 'TP': 3109, 'TN': 99938, 'Pos': 8427, 'desc': 'prc George'}, {'FN': 7208, 'Accuracy': 0.9210957744989159, 'model': 'rdg', 'Precision': 0.4114073574080324, 'name': 'Jason', 'Neg': 105027, 'FP': 1744, 'color': 'ro', 'Recall': 0.14465408805031446, 'TP': 1219, 'TN': 103283, 'Pos': 8427, 'desc': 'rdg Jason'}, {'FN': 7238, 'Accuracy': 0.9206991379766248, 'model': 'rdg', 'Precision': 0.4033242876526459, 'name': 'Kevin', 'Neg': 105027, 'FP': 1759, 'color': 'ro', 'Recall': 0.1410941022902575, 'TP': 1189, 'TN': 103268, 'Pos': 8427, 'desc': 'rdg Kevin'}, {'FN': 6241, 'Accuracy': 0.9389532321469495, 'model': 'lgs', 'Precision': 0.7614071752002787, 'name': 'Michael', 'Neg': 105027, 'FP': 685, 'color': 'go', 'Recall': 0.2594042957161505, 'TP': 2186, 'TN': 104342, 'Pos': 8427, 'desc': 'lgs Michael'}, {'FN': 7219, 'Accuracy': 0.9206638813968657, 'model': 'rdg', 'Precision': 0.4040133779264214, 'name': 'Nic', 'Neg': 105027, 'FP': 1782, 'color': 'ro', 'Recall': 0.14334875993829357, 'TP': 1208, 'TN': 103245, 'Pos': 8427, 'desc': 'rdg Nic'}, {'FN': 5980, 'Accuracy': 0.9085091755248823, 'model': 'svm', 'Precision': 0.3573827953848401, 'name': 'Phillip', 'Neg': 105027, 'FP': 4400, 'color': 'co', 'Recall': 0.290376171828646, 'TP': 2447, 'TN': 100627, 'Pos': 8427, 'desc': 'svm Phillip'}, {'FN': 6893, 'Accuracy': 0.9276975690588256, 'Pos': 2844, 'model': 'unspecified', 'name': 'Rik', 'color': 'yo', 'TP': 1534, 'TN': 103717, 'Neg': 110610, 'desc': 'unspecified Rik', 'FP': 1310}, {'FN': 7219, 'Accuracy': 0.9206726955418055, 'model': 'rdg', 'Precision': 0.40414854466376715, 'name': 'Rye', 'Neg': 105027, 'FP': 1781, 'color': 'ro', 'Recall': 0.14334875993829357, 'TP': 1208, 'TN': 103246, 'Pos': 8427, 'desc': 'rdg Rye'}, {'FN': 7465, 'Accuracy': 0.9230877712553105, 'model': 'svm', 'Precision': 0.4327485380116959, 'name': 'Steve', 'Neg': 105027, 'FP': 1261, 'color': 'co', 'Recall': 0.11415687670582651, 'TP': 962, 'TN': 103766, 'Pos': 8427, 'desc': 'svm Steve'}, {'FN': 7070, 'Accuracy': 0.9212103583831333, 'model': 'rdg', 'Precision': 0.42064476131432116, 'name': 'Yicen', 'Neg': 105027, 'FP': 1869, 'color': 'ro', 'Recall': 0.16103002254657647, 'TP': 1357, 'TN': 103158, 'Pos': 8427, 'desc': 'rdg Yicen'}]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 15)

# %%
for fit in grades:
    plt.plot(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], fit['color'])
    plt.text(fit['FP'] / fit['Neg'], 
             fit['TP'] / fit['Pos'], fit['name'] + ' ' + fit['model'])
plt.axis([0, 1, 0, 1])
plt.title('ROC plot: test set')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.figure(figsize=(50,50))
plt.show()
